# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

import numpy as np

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import cv2

(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()
X_train_flattened = X_train.reshape(len(X_train), 28*28)
X_test_flattened = X_test.reshape(len(X_test), 28*28)

X_train = X_train / 255
X_test = X_test / 255

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=10)

# Test our drawing numbers by hand on laptop 

image1 = cv2.imread(f'number_x.png',0)
image1 = cv2.resize(image1, (28,28))

image2 = cv2.imread(f'number_y.png',0)
image2 = cv2.resize(image2, (28,28))

image3 = cv2.imread(f'number_z.png',0)
image3 = cv2.resize(image3, (28,28))

image4 = cv2.imread(f'number_a.png',0)
image4 = cv2.resize(image4, (28,28))

data=[]
data.append(np.asarray(image1)/255.0)
data.append(np.asarray(image2)/255.0)
data.append(np.asarray(image3)/255.0)
data.append(np.asarray(image4)/255.0)

data=np.array(data)
y_predicted = model.predict(data)
print('Prection for these images: ', np.argmax(y_predicted[0]), np.argmax(y_predicted[1]), np.argmax(y_predicted[2]), np.argmax(y_predicted[3]))

#print(y_predicted)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8681 - loss: 0.4657
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9610 - loss: 0.1329
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9753 - loss: 0.0854
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9807 - loss: 0.0626
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9850 - loss: 0.0461
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9881 - loss: 0.0390
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9913 - loss: 0.0316
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9925 - loss: 0.0244
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9937 - loss: 0.0208
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9955 - loss: 0.0157
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Prection for these images:  3 9 4 5

# %%
plt.matshow(data[0])
plt.matshow(data[1])
plt.matshow(data[2])
plt.matshow(data[3])

# %%
plt.matshow(X_test[35])
plt.matshow(X_test[36])
plt.matshow(X_test[37])
plt.matshow(X_test[38])
plt.matshow(X_test[39])
plt.matshow(X_test[2])
plt.matshow(X_test[3])
plt.matshow(X_test[4])
plt.matshow(X_test[4])
plt.matshow(X_test[5])
plt.matshow(X_test[6])
plt.matshow(X_test[7])
plt.matshow(X_test[8])
plt.matshow(X_test[9])
plt.matshow(X_test[10])
plt.matshow(X_test[11])
plt.matshow(X_test[12])
plt.matshow(X_test[13])
plt.matshow(X_test[14])
plt.matshow(X_test[15])
plt.matshow(X_test[16])
plt.matshow(X_test[17])
# Out:
# /var/folders/9t/w3ssd05n1d55448h6pcjp_sm0000gn/T/ipykernel_73361/2994826753.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.matshow(X_test[16])
